# %% [markdown]
# <a href="https://colab.research.google.com/github/143211/TARUN_INFO5731/blob/main/Tarun_konda_Assignment_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment 2**
#
# In this assignment, you will work on gathering text data from an open data source via web scraping or API. Following this, you will need to clean the text data and perform syntactic analysis on the data. Follow the instructions carefully and design well-structured Python programs to address each question.
#
# **Expectations**:
# *   Use the provided .*ipynb* document to write your code & respond to the questions. Avoid generating a new file.
# *   Write complete answers and run all the cells before submission.
# *   Make sure the submission is "clean"; *i.e.*, no unnecessary code cells.
# *   Once finished, allow shared rights from top right corner (*see Canvas for details*).
#
# * **Make sure to submit the cleaned data CSV in the comment section - 10 points**
#
# **Total points**: 100
#
# **Deadline**: Wednesday, at 11:59 PM.
#
# **Late Submission will have a penalty of 10% reduction for each day after the deadline.**

# %% [markdown]
# # Question 1 (40 points)
#
# Write a python program to collect text data from **either of the following sources** and save the data into a **csv file:**
#
# (1) Collect all the customer reviews of a product (you can choose any porduct) on amazon. [atleast 1000 reviews]
#
# (2) Collect the top 1000 User Reviews of a movie recently in 2023 or 2024 (you can choose any movie) from IMDB. [If one movie doesn't have sufficient reviews, collect reviews of atleast 2 or 3 movies]
#
# (3) Collect all the reviews of the top 1000 most popular software from G2 or Capterra.
#
# (4) Collect the **abstracts** of the top 10000 research papers by using the query "machine learning", "data science", "artifical intelligence", or "information extraction" from Semantic Scholar.
#
# (5) Collect all the information of the 904 narrators in the Densho Digital Repository.

# %%
import requests
from bs4 import BeautifulSoup
import csv

def fetch_reviews(imdb_id):
    reviews = []
    url = f"https://www.imdb.com/title/{imdb_id}/reviews?ref_=tt_urv"
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Assuming each review is within a 'div' tag with a specific class.
    # This is a placeholder and might need adjustment based on actual page structure.
    review_divs = soup.find_all('div', class_='review-container')
    for div in review_divs:
        title = div.find('a', class_='title').text.strip()
        text = div.find('div', class_='text show-more__control').text.strip()
        try:
            rating = div.find('span', class_='rating-other-user-rating').span.text.strip()
        except AttributeError:
            rating = 'No Rating'

        reviews.append({'review_title': title, 'review_text': text, 'rating': rating})

    return reviews

def save_reviews_to_csv(reviews, filename):
    with open(filename, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.DictWriter(file, fieldnames=['review_title', 'review_text', 'rating'])
        writer.writeheader()
        for review in reviews:
            writer.writerow(review)

# Example usage
imdb_id = 'tt5433140'  # Example IMDb ID
reviews = fetch_reviews(imdb_id)
save_reviews_to_csv(reviews, 'Fastx_reviews.csv')

# %% [markdown]
# # Question 2 (30 points)
#
# Write a python program to **clean the text data** you collected in the previous question and save the clean data in a new column in the csv file. The data cleaning steps include: [Code and output is required for each part]
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the stopwords list.
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

# %%
df = pd.read_csv('Fastx_reviews.csv')

# %%
df['noise_removed'] = df['review_text'].apply(lambda x: re.sub(r'[^\w\s]', '', x))
df.head()
# Out:
#            review_title                                        review_text  \
# 0  Excruciatingly Awful  I thought they couldn't possibly write somethi...
# 1        What Happened?  I can write the exact same review for the last...
# 2    The worst one yet.  Fast & Furious 9 did what a lot of franchises ...
# 3                Fast X  By this point, I went to see Fast X without a ...
# 4     They need to stop  The movie starts it story from the first ten m...
#
#    rating                                      noise_removed
# 0       1  I thought they couldnt possibly write somethin...
# 1       1  I can write the exact same review for the last...
# 2       3  Fast  Furious 9 did what a lot of franchises d...
# 3       5  By this point I went to see Fast X without a c...
# 4       4  The movie starts it story from the first ten m...

# %%
df['numbers_removed'] = df['noise_removed'].apply(lambda x: re.sub(r'\d+', '', x))
df.head()
# Out:
#            review_title                                        review_text  \
# 0  Excruciatingly Awful  I thought they couldn't possibly write somethi...
# 1        What Happened?  I can write the exact same review for the last...
# 2    The worst one yet.  Fast & Furious 9 did what a lot of franchises ...
# 3                Fast X  By this point, I went to see Fast X without a ...
# 4     They need to stop  The movie starts it story from the first ten m...
#
#    rating                                      noise_removed  \
# 0       1  I thought they couldnt possibly write somethin...
# 1       1  I can write the exact same review for the last...
# 2       3  Fast  Furious 9 did what a lot of franchises d...
# 3       5  By this point I went to see Fast X without a c...
# 4       4  The movie starts it story from the first ten m...
#
#                                      numbers_removed
# 0  I thought they couldnt possibly write somethin...
# 1  I can write the exact same review for the last...
# 2  Fast  Furious  did what a lot of franchises do...
# 3  By this point I went to see Fast X without a c...
# 4  The movie starts it story from the first ten m...

# %%
df['lowercased'] = df['numbers_removed'].apply(lambda x: x.lower())
df.head()
# Out:
#            review_title                                        review_text  \
# 0  Excruciatingly Awful  I thought they couldn't possibly write somethi...
# 1        What Happened?  I can write the exact same review for the last...
# 2    The worst one yet.  Fast & Furious 9 did what a lot of franchises ...
# 3                Fast X  By this point, I went to see Fast X without a ...
# 4     They need to stop  The movie starts it story from the first ten m...
#
#    rating                                      noise_removed  \
# 0       1  I thought they couldnt possibly write somethin...
# 1       1  I can write the exact same review for the last...
# 2       3  Fast  Furious 9 did what a lot of franchises d...
# 3       5  By this point I went to see Fast X without a c...
# 4       4  The movie starts it story from the first ten m...
#
#                                      numbers_removed  \
# 0  I thought they couldnt possibly write somethin...
# 1  I can write the exact same review for the last...
# 2  Fast  Furious  did what a lot of franchises do...
# 3  By this point I went to see Fast X without a c...
# 4  The movie starts it story from the first ten m...
#
#                                           lowercased
# 0  i thought they couldnt possibly write somethin...
# 1  i can write the exact same review for the last...
# 2  fast  furious  did what a lot of franchises do...
# 3  by this point i went to see fast x without a c...
# 4  the movie starts it story from the first ten m...

# %%
# Assuming stopwords are downloaded and available
stop_words = set(stopwords.words('english'))
df['stopwords_removed'] = df['lowercased'].apply(lambda x: ' '.join([word for word in x.split() if word not in stop_words]))
df.head()
# Out:
#            review_title                                        review_text  \
# 0  Excruciatingly Awful  I thought they couldn't possibly write somethi...
# 1        What Happened?  I can write the exact same review for the last...
# 2    The worst one yet.  Fast & Furious 9 did what a lot of franchises ...
# 3                Fast X  By this point, I went to see Fast X without a ...
# 4     They need to stop  The movie starts it story from the first ten m...
#
#    rating                                      noise_removed  \
# 0       1  I thought they couldnt possibly write somethin...
# 1       1  I can write the exact same review for the last...
# 2       3  Fast  Furious 9 did what a lot of franchises d...
# 3       5  By this point I went to see Fast X without a c...
# 4       4  The movie starts it story from the first ten m...
#
#                                      numbers_removed  \
# 0  I thought they couldnt possibly write somethin...
# 1  I can write the exact same review for the last...
# 2  Fast  Furious  did what a lot of franchises do...
# 3  By this point I went to see Fast X without a c...
# 4  The movie starts it story from the first ten m...
#
#                                           lowercased  \
# 0  i thought they couldnt possibly write somethin...
# 1  i can write the exact same review for the last...
# 2  fast  furious  did what a lot of franchises do...
# 3  by this point i went to see fast x without a c...
# 4  the movie starts it story from the first ten m...
#
#                                    stopwords_removed
# 0  thought couldnt possibly write something even ...
# 1  write exact review last transformers last indi...
# 2  fast furious lot franchises point took action ...
# 3  point went see fast x without clue happened la...
# 4  movie starts story first ten minutes fast five...

# %%
ps = PorterStemmer()
df['stemmed'] = df['stopwords_removed'].apply(lambda x: ' '.join([ps.stem(word) for word in x.split()]))
df.head()
# Out:
#            review_title                                        review_text  \
# 0  Excruciatingly Awful  I thought they couldn't possibly write somethi...
# 1        What Happened?  I can write the exact same review for the last...
# 2    The worst one yet.  Fast & Furious 9 did what a lot of franchises ...
# 3                Fast X  By this point, I went to see Fast X without a ...
# 4     They need to stop  The movie starts it story from the first ten m...
#
#    rating                                      noise_removed  \
# 0       1  I thought they couldnt possibly write somethin...
# 1       1  I can write the exact same review for the last...
# 2       3  Fast  Furious 9 did what a lot of franchises d...
# 3       5  By this point I went to see Fast X without a c...
# 4       4  The movie starts it story from the first ten m...
#
#                                      numbers_removed  \
# 0  I thought they couldnt possibly write somethin...
# 1  I can write the exact same review for the last...
# 2  Fast  Furious  did what a lot of franchises do...
# 3  By this point I went to see Fast X without a c...
# 4  The movie starts it story from the first ten m...
#
#                                           lowercased  \
# 0  i thought they couldnt possibly write somethin...
# 1  i can write the exact same review for the last...
# 2  fast  furious  did what a lot of franchises do...
# 3  by this point i went to see fast x without a c...
# 4  the movie starts it story from the first ten m...
#
#                                    stopwords_removed  \
# 0  thought couldnt possibly write something even ...
# 1  write exact review last transformers last indi...
# 2  fast furious lot franchises point took action ...
# 3  point went see fast x without clue happened la...
# 4  movie starts story first ten minutes fast five...
#
#                                              stemmed
# 0  thought couldnt possibl write someth even wors...
# 1  write exact review last transform last indiana...
# 2  fast furiou lot franchis point took action out...
# 3  point went see fast x without clue happen last...
# 4  movi start stori first ten minut fast five sto...

# %%
# Assuming lemmatization data is available
lemmatizer = WordNetLemmatizer()
df['lemmatized'] = df['stemmed'].apply(lambda x: ' '.join([lemmatizer.lemmatize(word) for word in x.split()]))
df.head()
# Out:
#            review_title                                        review_text  \
# 0  Excruciatingly Awful  I thought they couldn't possibly write somethi...
# 1        What Happened?  I can write the exact same review for the last...
# 2    The worst one yet.  Fast & Furious 9 did what a lot of franchises ...
# 3                Fast X  By this point, I went to see Fast X without a ...
# 4     They need to stop  The movie starts it story from the first ten m...
#
#    rating                                      noise_removed  \
# 0       1  I thought they couldnt possibly write somethin...
# 1       1  I can write the exact same review for the last...
# 2       3  Fast  Furious 9 did what a lot of franchises d...
# 3       5  By this point I went to see Fast X without a c...
# 4       4  The movie starts it story from the first ten m...
#
#                                      numbers_removed  \
# 0  I thought they couldnt possibly write somethin...
# 1  I can write the exact same review for the last...
# 2  Fast  Furious  did what a lot of franchises do...
# 3  By this point I went to see Fast X without a c...
# 4  The movie starts it story from the first ten m...
#
#                                           lowercased  \
# 0  i thought they couldnt possibly write somethin...
# 1  i can write the exact same review for the last...
# 2  fast  furious  did what a lot of franchises do...
# 3  by this point i went to see fast x without a c...
# 4  the movie starts it story from the first ten m...
#
#                                    stopwords_removed  \
# 0  thought couldnt possibly write something even ...
# 1  write exact review last transformers last indi...
# 2  fast furious lot franchises point took action ...
# 3  point went see fast x without clue happened la...
# 4  movie starts story first ten minutes fast five...
#
#                                              stemmed  \
# 0  thought couldnt possibl write someth even wors...
# 1  write exact review last transform last indiana...
# 2  fast furiou lot franchis point took action out...
# 3  point went see fast x without clue happen last...
# 4  movi start stori first ten minut fast five sto...
#
#                                           lemmatized
# 0  thought couldnt possibl write someth even wors...
# 1  write exact review last transform last indiana...
# 2  fast furiou lot franchis point took action out...
# 3  point went see fast x without clue happen last...
# 4  movi start stori first ten minut fast five sto...

# %%
df['cleaned_text'] = df['lemmatized']
df.head()
# Out:
#            review_title                                        review_text  \
# 0  Excruciatingly Awful  I thought they couldn't possibly write somethi...
# 1        What Happened?  I can write the exact same review for the last...
# 2    The worst one yet.  Fast & Furious 9 did what a lot of franchises ...
# 3                Fast X  By this point, I went to see Fast X without a ...
# 4     They need to stop  The movie starts it story from the first ten m...
#
#    rating                                      noise_removed  \
# 0       1  I thought they couldnt possibly write somethin...
# 1       1  I can write the exact same review for the last...
# 2       3  Fast  Furious 9 did what a lot of franchises d...
# 3       5  By this point I went to see Fast X without a c...
# 4       4  The movie starts it story from the first ten m...
#
#                                      numbers_removed  \
# 0  I thought they couldnt possibly write somethin...
# 1  I can write the exact same review for the last...
# 2  Fast  Furious  did what a lot of franchises do...
# 3  By this point I went to see Fast X without a c...
# 4  The movie starts it story from the first ten m...
#
#                                           lowercased  \
# 0  i thought they couldnt possibly write somethin...
# 1  i can write the exact same review for the last...
# 2  fast  furious  did what a lot of franchises do...
# 3  by this point i went to see fast x without a c...
# 4  the movie starts it story from the first ten m...
#
#                                    stopwords_removed  \
# 0  thought couldnt possibly write something even ...
# 1  write exact review last transformers last indi...
# 2  fast furious lot franchises point took action ...
# 3  point went see fast x without clue happened la...
# 4  movie starts story first ten minutes fast five...
#
#                                              stemmed  \
# 0  thought couldnt possibl write someth even wors...
# 1  write exact review last transform last indiana...
# 2  fast furiou lot franchis point took action out...
# 3  point went see fast x without clue happen last...
# 4  movi start stori first ten minut fast five sto...
#
#                                           lemmatized  \
# 0  thought couldnt possibl write someth even wors...
# 1  write exact review last transform last indiana...
# 2  fast furiou lot franchis point took action out...
# 3  point went see fast x without clue happen last...
# 4  movi start stori first ten minut fast five sto...
#
#                                         cleaned_text
# 0  thought couldnt possibl write someth even wors...
# 1  write exact review last transform last indiana...
# 2  fast furiou lot franchis point took action out...
# 3  point went see fast x without clue happen last...
# 4  movi start stori first ten minut fast five sto...

# %%
df.to_csv('Fastx_cleaned_reviews.csv', index=False)
df.head()
# Out:
#            review_title                                        review_text  \
# 0  Excruciatingly Awful  I thought they couldn't possibly write somethi...
# 1        What Happened?  I can write the exact same review for the last...
# 2    The worst one yet.  Fast & Furious 9 did what a lot of franchises ...
# 3                Fast X  By this point, I went to see Fast X without a ...
# 4     They need to stop  The movie starts it story from the first ten m...
#
#    rating                                      noise_removed  \
# 0       1  I thought they couldnt possibly write somethin...
# 1       1  I can write the exact same review for the last...
# 2       3  Fast  Furious 9 did what a lot of franchises d...
# 3       5  By this point I went to see Fast X without a c...
# 4       4  The movie starts it story from the first ten m...
#
#                                      numbers_removed  \
# 0  I thought they couldnt possibly write somethin...
# 1  I can write the exact same review for the last...
# 2  Fast  Furious  did what a lot of franchises do...
# 3  By this point I went to see Fast X without a c...
# 4  The movie starts it story from the first ten m...
#
#                                           lowercased  \
# 0  i thought they couldnt possibly write somethin...
# 1  i can write the exact same review for the last...
# 2  fast  furious  did what a lot of franchises do...
# 3  by this point i went to see fast x without a c...
# 4  the movie starts it story from the first ten m...
#
#                                    stopwords_removed  \
# 0  thought couldnt possibly write something even ...
# 1  write exact review last transformers last indi...
# 2  fast furious lot franchises point took action ...
# 3  point went see fast x without clue happened la...
# 4  movie starts story first ten minutes fast five...
#
#                                              stemmed  \
# 0  thought couldnt possibl write someth even wors...
# 1  write exact review last transform last indiana...
# 2  fast furiou lot franchis point took action out...
# 3  point went see fast x without clue happen last...
# 4  movi start stori first ten minut fast five sto...
#
#                                           lemmatized  \
# 0  thought couldnt possibl write someth even wors...
# 1  write exact review last transform last indiana...
# 2  fast furiou lot franchis point took action out...
# 3  point went see fast x without clue happen last...
# 4  movi start stori first ten minut fast five sto...
#
#                                         cleaned_text
# 0  thought couldnt possibl write someth even wors...
# 1  write exact review last transform last indiana...
# 2  fast furiou lot franchis point took action out...
# 3  point went see fast x without clue happen last...
# 4  movi start stori first ten minut fast five sto...

# %% [markdown]
# # Question 3 (30 points)
#
# Write a python program to **conduct syntax and structure analysis of the clean text** you just saved above. The syntax and structure analysis includes:
#
# (1) **Parts of Speech (POS) Tagging:** Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) **Constituency Parsing and Dependency Parsing:** print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) **Named Entity Recognition:** Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
# !pip install nltk
# !python -m nltk.downloader averaged_perceptron_tagger
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)
# /usr/lib/python3.10/runpy.py:126: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
import nltk
nltk.download('punkt')
nltk.download('words')
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# True

# %%
import pandas as pd
import spacy
import nltk
from nltk import pos_tag, ne_chunk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tree import Tree
from collections import Counter

# Load the spaCy English model for dependency parsing and named entity recognition.
nlp = spacy.load("en_core_web_sm")

# Function to print constituency parsing tree using NLTK.
def print_constituency_tree(text):
    """Prints the constituency parsing tree of a text using NLTK."""
    sentences = nltk.sent_tokenize(text)
    for sentence in sentences:
        words = nltk.word_tokenize(sentence)
        tagged = pos_tag(words)
        chunked = ne_chunk(tagged)
        for subtree in chunked:
            if type(subtree) == Tree:
                print(subtree.label(), " ".join(word for word, pos in subtree.leaves()))
            else:
                print(subtree[0], subtree[1])

# Function to print dependency parsing tree using spaCy.
def print_dependency_tree(text):
    """Prints the dependency parsing tree of a text using spaCy."""
    doc = nlp(text)
    for token in doc:
        print(f"{token.text} --> {token.dep_} --> {token.head.text}, children: {[child for child in token.children]}")

# Function to extract named entities and count their occurrences.
def extract_named_entities(text):
    """Extracts named entities from the text and counts their occurrences."""
    doc = nlp(text)
    entity_counter = Counter()
    for ent in doc.ents:
        entity_counter[ent.label_] += 1
    return entity_counter

# Load the cleaned text from the CSV file, focusing on the first 20 rows.
df = pd.read_csv("Fastx_cleaned_reviews.csv", nrows=20)

# Combine the cleaned text from these rows into a single string for analysis.
combined_text = " ".join(df['cleaned_text'].tolist())

# (1) POS Tagging
tokens = word_tokenize(combined_text)
pos_tags = pos_tag(tokens)
noun_count = len([word for word, pos in pos_tags if pos.startswith('N')])
verb_count = len([word for word, pos in pos_tags if pos.startswith('V')])
adj_count = len([word for word, pos in pos_tags if pos.startswith('J')])
adv_count = len([word for word, pos in pos_tags if pos.startswith('R')])

print(f"Total Nouns: {noun_count}")
print(f"Total Verbs: {verb_count}")
print(f"Total Adjectives: {adj_count}")
print(f"Total Adverbs: {adv_count}")

# (2) Constituency Parsing and Dependency Parsing
print("Constituency Parsing Trees:")
print_constituency_tree(combined_text)
print("\nDependency Parsing Tree:")
print_dependency_tree(combined_text)

# (3) Named Entity Recognition
entity_counter = extract_named_entities(combined_text)
print("Named Entities:")
for entity, count in entity_counter.items():
    print(f"{entity}: {count}")
# Out:
# Streaming output truncated to the last 5000 lines.
# move NN
# street NN
# race NN
# world NN
# jame NN
# bond NN
# territori JJ
# action NN
# get VB
# ridicul JJ
# chapter NN
# see NN
# movi NN
# would MD
# top VB
# one CD
# term NN
# crazi NN
# kept VBD
# entertain JJ
# fast JJ
# x NN
# dumb VBD
# even RB
# dumb JJ
# funth JJ
# stunt NN
# preposter NN
# ever RB
# film NN
# never RB
# thrill VB
# everi JJ
# intermin JJ
# action NN
# scene NN
# enhanc VBP
# rather RB
# ropey JJ
# cgi NN
# flame NN
# particular JJ
# look NN
# realli NN
# bad JJ
# dread JJ
# attempt NN
# humour NN
# mostli NN
# courtesi NN
# tyre NN
# gibson NN
# ludacri NN
# get VBP
# inevit JJ
# crap NN
# import NN
# famili VBD
# see VB
# gang JJ
# anoth DT
# barbecu JJ
# think NN
# ill NN
# hurland VBP
# there EX
# jason NN
# momoa NN
# villain NN
# dantei NN
# see VBP
# go VB
# kooki JJ
# flamboy NN
# psycho NN
# capabl NN
# almost RB
# anyth JJ
# momoa NN
# absolut NN
# aw NN
# perform VB
# border NN
# camp NN
# help NN
# charact VB
# dubiou JJ
# choic NN
# attir RB
# hard JJ
# find VBP
# dant JJ
# menac NN
# he PRP
# flounc VBZ
# silki JJ
# shirt NN
# ill JJ
# doubt NN
# watch NN
# next IN
# two CD
# film NN
# sake VBP
# complet NN
# momoa NNP
# board NN
# itll VBZ
# hard JJ
# goingfast NN
# x NNP
# easili NN
# weakest JJS
# seri NN
# far RB
# ill RB
# give VB
# guess JJ
# thing NN
# could MD
# get VB
# even RB
# wors NNS
# point VBP
# went VBD
# see VB
# fast JJ
# x NN
# without IN
# clue NN
# happen NN
# last JJ
# one CD
# think NN
# peopl NN
# went VBD
# spaceth JJ
# ff NN
# seri VBD
# one CD
# villain NN
# becom NN
# friend NN
# peopl VBZ
# come VBN
# back RB
# dead JJ
# car NN
# defi NN
# law NN
# physic VBP
# one CD
# idea NN
# stori NN
# soon RB
# watch VBD
# ita JJ
# plot NN
# inspir NN
# fast JJ
# stole JJ
# safe JJ
# rode NN
# along IN
# street NN
# rio NN
# de IN
# janeirodant NN
# rey NN
# jason NN
# momoa FW
# sociopath NN
# son NN
# hernan NN
# rey NN
# joaquim NN
# de FW
# almeida FW
# want VBP
# make NN
# dom NN
# toretto NN
# famili NN
# suffer VBP
# happen VB
# dadth NN
# main JJ
# action NN
# start RB
# drop VBZ
# big JJ
# roll NN
# bomb NN
# rome VBD
# aim NN
# vaticanplagu NN
# behind IN
# scene NN
# issu JJ
# origin NN
# director NN
# justin NN
# lin JJ
# depart RB
# soon RB
# shoot JJ
# start NN
# director NN
# loui VBD
# leterri JJ
# workmanlik JJ
# job NN
# show NN
# netflix JJ
# seri NN
# lupin NN
# see VBP
# well RB
# transport VB
# movi NN
# car NN
# stunt NN
# well RB
# sleight JJ
# hand NN
# cgi NNS
# look VBP
# cheap JJ
# thougha NN
# momoa NNS
# director NN
# obvious JJ
# told VBD
# man NN
# never RB
# play VB
# joker NN
# polynesian JJ
# dant NN
# joker NN
# dial JJ
# loud NN
# camp NN
# ball NN
# especi VBP
# two CD
# guy NN
# funni NN
# grin NN
# facessom VBP
# regular JJ
# even RB
# tiresom VBP
# show VBP
# like IN
# two CD
# brazilian JJ
# guy NN
# earlier RBR
# movi NN
# john NN
# cena NN
# play NN
# lovabl VBZ
# uncl JJ
# jacob NN
# main JJ
# villain NN
# last JJ
# oneth JJ
# movi VBD
# actual JJ
# four CD
# oscar NN
# win NN
# actress NN
# one CD
# told VBD
# vin NN
# diesel NN
# dramat NN
# dom NN
# small JJ
# tender NN
# scene NN
# nearli NN
# fell VBD
# asleep RB
# movi JJ
# start NN
# stori NN
# first RB
# ten JJ
# minut NN
# fast RB
# five CD
# stori JJ
# start NN
# nowher CC
# thr JJ
# scene NN
# even RB
# connect JJ
# properli NNS
# scene VBP
# come VBP
# nowher RB
# perform JJ
# cast NN
# member NN
# felt VBD
# weak JJ
# charact NN
# develop VB
# main JJ
# villian JJ
# bad JJ
# jason NN
# charact NN
# want VBP
# reveng NN
# movi JJ
# look NN
# like IN
# psycho NN
# kill NN
# peopl VBZ
# fun NN
# main JJ
# problem NN
# franchis NN
# satur NN
# feel VBP
# like IN
# seen VBN
# million CD
# time NN
# action NN
# scene NN
# doesnt NN
# amaz VBZ
# youoveral JJ
# averag JJ
# action NN
# movi VBD
# franchis JJ
# reach NN
# fatigu NN
# admit NN
# peopl NN
# forewarn NN
# still RB
# didnt VBZ
# prepar JJ
# absolut JJ
# ridicul NN
# movi NN
# franchis JJ
# definit NN
# top JJ
# worst NN
# movi NN
# ever RB
# everyth VBZ
# forc JJ
# act NN
# stale JJ
# wooden JJ
# nobodi NN
# seem VBP
# care JJ
# look NN
# like IN
# stroke NN
# vin NN
# ego NN
# care NN
# came VBD
# across IN
# go JJ
# motion NN
# movi NN
# le NN
# plot NN
# wiley NN
# coyot NN
# roadrunn NN
# momoa NN
# cheap JJ
# imit NN
# ledger NN
# joker NN
# everi IN
# part NN
# movi VBP
# one CD
# lift NN
# previou NN
# movi NN
# car NN
# outer NN
# space NN
# time NN
# better RBR
# year NN
# old JJ
# version NN
# fast RB
# furiou JJ
# fast RB
# blatant JJ
# rip NN
# point NN
# break NN
# walker NN
# keanu VBD
# johnni JJ
# utah JJ
# vin NN
# swayz NN
# bohdi NN
# instead RB
# surf JJ
# car NN
# actual JJ
# rob NN
# bank NN
# two CD
# movi NN
# never RB
# made VBD
# contain NN
# noth RB
# made VBD
# group NN
# film NN
# popular JJ
# next JJ
# one CD
# hope NN
# last JJ
# forev JJ
# whoever WP
# gave VBD
# somebodi JJ
# relat JJ
# someon NN
# movi NN
# year NN
# old JJ
# bad JJ
# wasnt NN
# even RB
# funni RBR
# torment NN
# last JJ
# almost RB
# hour NN
# non JJ
# stop NN
# chao NN
# pointless NN
# plot NN
# go VBP
# back RB
# forth RB
# mani JJ
# storylin NN
# connect NN
# understand VBP
# dont NN
# want VBP
# wast IN
# hour NN
# life NN
# skip NN
# watch NN
# looney NN
# tune NN
# superior JJ
# everi JJ
# way NN
# know VBP
# deal NN
# famili NN
# fast JJ
# car NN
# hot JJ
# girlsnot NN
# mani JJ
# time NN
# alist JJ
# celebr NN
# cheesi NN
# dialogu NN
# stori FW
# wrap NN
# high JJ
# budget NN
# movi NN
# bare NN
# make VBP
# sen JJ
# suppos NNS
# make VBP
# sen NN
# cours NNS
# even RB
# ever RB
# attempt VB
# convey JJ
# street NN
# race NN
# cultur NN
# begin VB
# franchis JJ
# gone VBN
# replac JJ
# forgett JJ
# action NN
# flick NN
# deserv NN
# stream NN
# releaseif NN
# went VBD
# cinema NN
# bore NN
# fest JJS
# pointless NN
# explos NN
# feel VBP
# bad JJ
# even RB
# go VBP
# stori JJ
# save VBP
# grace NN
# movi NN
# point NN
# polish JJ
# cg NN
# well RB
# done VBN
# stunt NN
# societi NN
# favor NN
# stop VB
# reward NN
# mindless JJ
# micheal NN
# bay NN
# movi NN
# huge JJ
# fan NN
# fast RB
# furiou JJ
# seri NN
# vin NN
# diesel NN
# although IN
# physicist JJ
# live VBP
# curb NN
# law NN
# natur NN
# extent NN
# provid NN
# justifi NN
# eg NN
# scifi NN
# magic JJ
# altern JJ
# univers NNS
# etc VBP
# also RB
# ok JJ
# movi NNS
# like IN
# mission NN
# imposs IN
# similar JJ
# drive JJ
# thing NN
# extrem NN
# howev NN
# physic JJ
# logic NN
# go VBP
# awri JJ
# simpli NN
# muchth NN
# main JJ
# villain NN
# stori NN
# dant JJ
# play NN
# amaz NN
# jason NN
# mamoa NN
# simpli NN
# joke VBD
# super JJ
# intellig NN
# super NN
# rich JJ
# super JJ
# power NN
# caricatur NN
# sociopath NN
# à NNP
# la NN
# joker NN
# abl VBZ
# organ JJ
# crime NN
# pure NN
# driven VBN
# hatr NNS
# perfect JJ
# time NN
# across IN
# globe NN
# access NN
# everi NN
# possibl NN
# comput NN
# abil JJ
# surpass NN
# robert NN
# langdon NN
# foe NN
# davinc NN
# code NN
# thano NN
# aveng NN
# jame NN
# bond NN
# enemi JJ
# border NN
# ridicul NN
# importantli NNS
# make VBP
# film NN
# boringin NN
# next IN
# episod NN
# go VBP
# probabl JJ
# spaceship NN
# race NN
# across IN
# galaxi NN
# guess NN
# dant NN
# use NN
# nuclear JJ
# fusion NN
# killact NN
# gener NN
# decent JJ
# good JJ
# well RB
# shakespear JJ
# utterli JJ
# import NN
# cinematographi NN
# refer VBP
# effect NN
# excel NN
# unfortun JJ
# nice JJ
# packag NN
# salvag NN
# realli NN
# bad JJ
# contentfin NN
# realli NN
# abhor NN
# cliffhang NN
# seldom NN
# ever RB
# seen VBN
# infuri NN
# one CD
# one CD
# thing NN
# leav JJ
# thing NN
# open JJ
# stori NN
# quit NN
# differ VBP
# one CD
# liter JJR
# stop NN
# action NN
# middl NN
# intens VBZ
# scene NN
# like IN
# someon NN
# pull NN
# plug NN
# tv NN
# practic JJ
# mean NN
# produc NN
# sure JJ
# viewer NN
# watch NN
# next IN
# one CD
# use NN
# everi JJ
# mean NN
# anim NN
# plain NN
# aw IN
# tastelessin JJ
# whole JJ
# far RB
# worst JJS
# otherwis RB
# good JJ
# seri NNS
# realli VBP
# want VBP
# watch NN
# least JJS
# wait JJ
# next JJ
# one CD
# come NN
# save NN
# frustrat VBN
# unfinish JJ
# scene NN
# fast JJ
# x NNP
# final JJ
# went VBD
# fara NN
# far RB
# rememb VBZ
# peopl JJ
# keep VB
# complain NN
# movi NN
# dumb JJ
# howev NN
# peopl NN
# often RB
# dismiss JJ
# charm NN
# action NN
# overcompl IN
# plot NN
# crazi JJ
# writer NN
# tri NN
# show VB
# smart JJ
# time NN
# actual JJ
# went VBD
# faronc JJ
# retcon NN
# old JJ
# movi NN
# ad NN
# scene NN
# werent NN
# got VBD
# caught JJ
# reveng NN
# plot NN
# famili VBD
# come JJ
# togeth NNS
# defeat VBP
# evil JJ
# quit NN
# literallu NN
# rehash NN
# plot NN
# last JJ
# movi JJ
# time NN
# got VBD
# lazyth JJ
# whole JJ
# famili NN
# vack NN
# qith NN
# brand NN
# new JJ
# castallan NN
# ritchson NN
# love NN
# guy NN
# cant NN
# act NN
# save VBP
# life NN
# funniest JJS
# dialogu NN
# entir NN
# movi NN
# thoughalison NN
# brie IN
# second JJ
# wors NNS
# actor VBP
# entir JJ
# movi NN
# absolut NN
# chemistri NN
# entir NN
# cast VBD
# actual JJ
# impress NN
# seem VBP
# uncomfort JJ
# everi JJ
# scene NN
# dont NN
# get VBP
# itjohn JJ
# cena NNS
# charm VBP
# way NN
# make VBP
# like IN
# charact NN
# cant NN
# act NN
# either CC
# actual JJ
# take NN
# advantag NN
# dialogu NN
# phisic JJ
# sell NN
# jacob NN
# torettoand NN
# jason NN
# momoa NN
# play NN
# goofier NN
# joker NN
# jare NN
# leto NN
# would MD
# proud VB
# he PRP
# even RB
# ob VBD
# color NN
# purpl NN
# someon NN
# mustv NN
# felt VBD
# cheeki NN
# said VBD
# someth JJ
# line NN
# dont NN
# wan VBD
# na NNS
# kill VB
# want VBP
# hurt VBN
# real JJ
# bad JJ
# failur NN
# villain NN
# jump NN
# back RB
# forward RB
# seriou NN
# villain NN
# clownthi JJ
# overal JJ
# dull NN
# uninterest JJS
# bore NN
# disappoint NN
# fast RB
# shoulda VBD
# last JJ
# onenot JJ
# look VB
# forward RB
# sequel NN
# mess NN
# first RB
# car NN
# action NN
# great JJ
# lot NN
# imagin NN
# lot NN
# cgi VBZ
# great JJ
# locationsinbetween JJ
# get VB
# asskick JJ
# much RB
# ordinaryfollow IN
# hate NN
# scene NN
# get VBP
# emot JJ
# sceneslik NN
# love NN
# famili NN
# everyth NN
# cours NN
# die NN
# go VBP
# back RB
# hatediesel RB
# bad JJ
# actor NN
# imposs NN
# accept IN
# emot JJ
# scene NN
# love VBP
# hate NN
# evolv JJ
# year NN
# film NN
# noth DT
# primit NN
# emot VBZ
# brainlessjason JJ
# momoa NN
# bad JJ
# guy NN
# follow VB
# minor JJ
# bad JJ
# guy NN
# charact NN
# top JJ
# obvious JJ
# enjoy NN
# act NN
# maniac JJ
# joke NN
# bad JJ
# tast NN
# funni NN
# allhi JJ
# scene NN
# one CD
# worth NN
# watch NN
# along IN
# fake JJ
# comput NN
# gener NN
# car NN
# stunt NN
# throw VBP
# overboard RB
# basic JJ
# law NN
# physic NN
# incred VBD
# mani JJ
# stuntmen NNS
# visual JJ
# effect NN
# expert NN
# work NN
# movi NN
# suppos VB
# one CD
# work NN
# second JJ
# scene NN
# need NN
# paid VBN
# sure JJ
# take NN
# hell NN
# resourc VBZ
# manag NNS
# make VBP
# coher JJ
# finish JJ
# productth NN
# music NN
# annoy NN
# stunt NN
# loud JJ
# brain NN
# killerfor JJ
# budget NN
# mio NN
# usd JJ
# lot NN
# star NN
# appear VBP
# second JJ
# like IN
# visit NN
# attract NN
# peopl NN
# theatr NN
# keep VB
# money NN
# flow NN
# leav NN
# looti VBZ
# wont JJ
# name NN
# dont NN
# want VBP
# acomplic JJ
# decept NN
# late JJ
# medium NN
# guru NN
# marshal NN
# mcluhan NN
# offer VBP
# world NN
# interest NN
# meme NN
# call NN
# medium NN
# ecolog NN
# final JJ
# acknowledg NN
# resourc NN
# use NN
# medium NN
# preciou NN
# drew VBD
# attent JJ
# wast NN
# nobodi NN
# el VBP
# ever RB
# notic RB
# much JJ
# like IN
# current JJ
# upsidedown JJ
# age NN
# nobodi JJ
# notic JJ
# rare JJ
# earth NN
# resourc VBP
# need MD
# make VB
# electr JJ
# car NN
# standard JJ
# term NN
# medium NN
# ecolog NN
# may MD
# wast VB
# movi NN
# produc NN
# decad NN
# actor NN
# prop NN
# stunt NN
# devot NN
# shut VBD
# franchis JJ
# blew NN
# tire NN
# year NN
# ago RB
# never RB
# got VBD
# patch JJ
# sheer NN
# incompet NN
# script NN
# clear JJ
# charact NN
# momoa NN
# tri RB
# hard JJ
# breath NN
# life NN
# fail VBP
# time NN
# big JJ
# final JJ
# roll NN
# highway NN
# mark NN
# poor JJ
# viewer NN
# longer RBR
# root NN
# good JJ
# guy NN
# bad JJ
# guy NN
# father NN
# time NN
# arriv JJ
# end NN
# spectacl NN
# career NN
# burn NN
# conflagr NN
# design NN
# imdb JJ
# top JJ
# review NN
# plea NN
# check NN
# list NN
# nearlyperfect JJ
# movi JJ
# occasion NN
# anim JJ
# tv NN
# miniseri NN
# canshould NN
# see VB
# present JJ
# mission NN
# walk NN
# theater NN
# count NN
# number NN
# famili VBP
# spoken VBN
# movi JJ
# end NN
# day NN
# got VBD
# familia JJ
# fam NN
# grand JJ
# total JJ
# famili NN
# see VBP
# break NN
# record NN
# next IN
# timenoth NN
# much JJ
# need MD
# comment VB
# film NN
# launch NN
# car NN
# space NN
# last JJ
# time NN
# destroy JJ
# satellit NN
# le NN
# could MD
# expect VB
# screw JJ
# logist JJ
# screw NN
# physic JJ
# screw VBD
# newton JJ
# screw NN
# appl NN
# tree NN
# guess NN
# manag NN
# stay NN
# awak IN
# hour NN
# youll JJ
# start NN
# understand NN
# ff VBP
# actual JJ
# surviv NN
# year NN
# journey NN
# product NN
# give VB
# screw NN
# hey NN
# rememb VBP
# gal JJ
# gadot NN
# charact NN
# got VBD
# blew JJ
# yeah NN
# screw VBD
# quit JJ
# dcu NN
# resurrect NN
# univers NNS
# rememb VBP
# jakob JJ
# coldblood NN
# villain NN
# one CD
# movi NN
# screw VBD
# got VBD
# peacemak JJ
# play NN
# time NN
# cuz JJ
# make VBP
# great JJ
# comedi NN
# rememb VBD
# even RB
# dune JJ
# dare NN
# announc NN
# sequel NN
# first RB
# week NN
# releas NNS
# screw VBD
# villeneuv JJ
# aint NN
# know VBP
# noth DT
# make VBP
# sequel NN
# bring NN
# fast RB
# calendar JJ
# releas NNS
# trailerso VBP
# yeah RB
# anticip JJ
# fast RB
# next JJ
# year NN
# man NN
# name NN
# domin JJ
# iamgroot NN
# toretto NN
# assert JJ
# dominion NN
# dant NN
# joker NN
# aquaman NN
# cours VBZ
# help NN
# famili VB
# fast RB
# xa JJ
# big JJ
# splashi NN
# pile IN
# rubbish JJ
# plot NN
# poor JJ
# rehash NN
# former JJ
# movi NNS
# noth DT
# new JJ
# compel NN
# itth NN
# perform NN
# cast VBD
# mostli JJ
# bland NN
# except IN
# jason NN
# momoa NN
# john NN
# cena NN
# impass NN
# drab NN
# portray NN
# domin NN
# toretto NN
# vin NN
# diesel NN
# especi NN
# frustrat NN
# meant VBD
# begin JJ
# end VB
# franchis JJ
# support NN
# charact NN
# numer NN
# due JJ
# short JJ
# screentim NN
# unceremoni JJ
# entri NN
# seem VBP
# like IN
# endless JJ
# introduct NN
# cameo NN
# jason NN
# momoa NN
# villain NN
# movi NN
# best RBS
# thing NN
# he PRP
# charismat VBZ
# campi JJ
# jokeresqu NN
# perform NN
# refresh NN
# john NN
# cena NN
# also RB
# give VBP
# good JJ
# perform NN
# good JJ
# blend NN
# bravado NN
# hilaritythi NN
# franchis NN
# hing VBG
# farfetch JJ
# action NN
# instal JJ
# sheer NN
# dumb NN
# funni NN
# ridicul VB
# former JJ
# instal JJ
# absent NN
# cgi NN
# good JJ
# direct JJ
# edit NN
# choppi NN
# time NN
# especi JJ
# poor JJ
# see NN
# sixth JJ
# expens VBZ
# movi NN
# ever RB
# made VBD
# wonder JJR
# money NN
# went VBD
# probabl JJ
# sprawl NN
# uninterest JJS
# cast NN
# origin NN
# fast RB
# furiou JJ
# copi NNS
# point NN
# break NN
# success NN
# masterpiec NN
# later RB
# becom VBD
# cult NN
# classic JJ
# exchang NN
# surf NN
# board NN
# car NN
# work NN
# guarante NN
# sequel NN
# diesel NN
# interest NN
# replac NN
# tyre IN
# gibson NN
# movi NN
# highli NN
# success NN
# produc NN
# decid NN
# cheap VBP
# one CD
# tokyo JJ
# end NN
# diesel NN
# cameo NN
# grant NN
# fourth JJ
# installmentth JJ
# fourth JJ
# part NN
# origin NN
# protagonist NN
# made VBD
# money NN
# diesel NN
# becom VBP
# one CD
# produc NN
# higher JJR
# budget NN
# spectacular JJ
# scene NN
# becam NN
# absolut VBZ
# blockbusterthat IN
# luck NN
# last JJ
# next JJ
# four CD
# movi NN
# keep VB
# mostli NN
# cast NN
# minu NN
# dead JJ
# came VBD
# back RB
# life NN
# strongli NN
# villain NN
# spectacular JJ
# almost RB
# realist NN
# scenesweil JJ
# case NN
# good JJ
# thing NN
# momoa NN
# bad JJ
# guy NN
# fun NN
# john NN
# cena NN
# kind NN
# sympathet JJ
# monsterth NN
# rest NN
# cast VBD
# good JJ
# usual JJ
# littl NN
# littl NN
# interact JJ
# dieseldiesel JJ
# complet NN
# disast NN
# bare NN
# act NN
# basic JJ
# superman JJ
# thief NN
# origin NN
# becam NN
# gener NN
# love IN
# person NN
# care NN
# famili NN
# friendsloui NN
# leterri JJ
# usual JJ
# good JJ
# action NN
# movi NNS
# director NN
# use VBP
# lower JJR
# budget NN
# movi NN
# seem VBP
# confort NN
# oneth VBP
# special JJ
# effect NN
# poor JJ
# last JJ
# sequenc NN
# realli VBD
# lame JJ
# cheap RB
# made VBD
# movi JJ
# overload JJ
# fight NN
# sequenc NN
# littl NN
# car NN
# one CD
# fact NN
# spectacular JJ
# one CD
# show NN
# ff JJ
# time NN
# movieto NNS
# make VBP
# matter NN
# wors NNS
# script VBP
# absurd JJ
# overli NN
# long RB
# minut RB
# movi JJ
# end NN
# leav NN
# open JJ
# x NNP
# xiin NNP
# brief NN
# lose JJ
# time NN
# obvious JJ
# intent NN
# squeez NN
# franchis NNS
# make VBP
# extra JJ
# buck NN
# least JJS
# tri JJ
# keep JJ
# level NN
# previou NN
# movi NN
# ff NN
# seri NN
# die NN
# logic JJ
# end NN
# paul NN
# die NN
# ff NN
# last JJ
# good JJ
# film NN
# seri VBP
# actual JJ
# poor JJ
# kid NN
# steal NN
# upgrad JJ
# car NN
# fro NN
# love VB
# race NN
# car NN
# space NN
# burn NN
# giant NN
# ball NN
# bomb NN
# azkaban JJ
# prizon NN
# gaysloppi NN
# aveng IN
# noth DT
# origin JJ
# vibe NN
# magic NN
# watch VBP
# drunk NN
# bore NN
# cross NN
# line NN
# cant JJ
# imagin NN
# money NN
# actor NN
# get VBP
# play VB
# there RB
# famili JJ
# fan NN
# whatev NN
# shame NN
# record NN
# money NN
# imagin NN
# money NN
# went VBD
# good JJ
# caus NN
# cheap JJ
# expens NNS
# effect NN
# idiot VBP
# plot NN
# like IN
# ff JJ
# dont NN
# surprisingli JJ
# interest NN
# entertain NN
# charact NN
# film NN
# jacob NN
# play NN
# john NN
# cena NN
# guess NN
# wrestler NN
# know VBP
# entertain VBP
# peopl JJ
# someth NN
# filmmak NN
# appar NN
# forgotteni NN
# expect VBP
# noth DT
# good JJ
# previou NN
# film NN
# didnt NN
# expect VBP
# anyth IN
# bad JJ
# charact NN
# dom NN
# letti JJ
# badli NN
# written VBN
# hurt VBN
# could MD
# let VB
# main JJ
# charact VB
# drop NN
# ball NN
# like IN
# thisspeak JJ
# ball NN
# idea NN
# giant NN
# round VBD
# bomb IN
# deton NN
# bodi NN
# water NN
# stolen VBN
# batman IN
# franchis JJ
# even RB
# capabl VBP
# creat NN
# anyth JJ
# origin NN
# anymoreth RB
# rest JJ
# famili NN
# continu NNS
# trend NN
# becom NN
# unwatch VBP
# unbear JJ
# new JJ
# instalmentthey NN
# probabl VBP
# decid NN
# cliché NN
# annoy NN
# kid NN
# charact NN
# tri JJ
# behav NN
# like IN
# adult NN
# comic JJ
# relief NN
# good JJ
# idea NN
# wasnt NNS
# kid VBP
# way NN
# look VBP
# like IN
# neither DT
# parent NN
# look NN
# like IN
# babi NN
# dom NN
# brought VBD
# home CD
# year NN
# ago RB
# felt VBD
# connect JJ
# boy NN
# belov NN
# charact NN
# elena NN
# dombut NN
# cours VBZ
# get VBP
# wors NNS
# subject JJ
# pure NN
# tortur NN
# toler NN
# talentless NN
# uncharismat JJ
# actress NN
# franchis NN
# ever RB
# seen VBN
# brie NNS
# larson RBR
# want VBP
# put VBN
# head NN
# oven RB
# everi JJ
# time NN
# open JJ
# mouth NN
# mean VBP
# didnt NN
# even RB
# tri JJ
# hide NN
# fact NN
# mostli CD
# two CD
# word NN
# titl NN
# copypast NN
# sentenc NN
# differ NN
# order NN
# one CD
# paragraph NN
# race NN
# victor NN
# race NN
# heat NN
# race NN
# rival JJ
# race NN
# independ NN
# race NN
# maverick NN
# race NN
# tranquil NN
# race NN
# liberti NN
# race NN
# bliss JJ
# race NN
# winner NN
# race NN
# explor NN
# race NN
# heaven NN
# mani FW
# mani NN
# titl JJ
# start NN
# race NN
# obviou NN
# pattern NN
# differ VBP
# titl NN
# wordsthi NN
# world NN
# record NN
# bogu NN
# chatgpt NN
# review NN
# mean JJ
# pretti NN
# bad JJ
# produc NN
# stoop NN
# low JJ
# theyr NN
# lazi VBD
# even RB
# hide JJ
# fact NN
# tri IN
# fool NN
# audienc NN
# way NN
# also RB
# prove VBP
# littl JJ
# faith NN
# film NN
# current JJ
# rotten NN
# tomato JJ
# critic JJ
# rate NN
# accur NNS
# gave VBD
# gener NN
# bad JJ
# effort NN
# didnt NN
# go VBP
# write JJ
# svfx NNS
# need VBP
# major JJ
# tone NN
# lack NN
# realism NN
# put VBD
# toward IN
# tri NN
# fool NN
# fan NN
# franchis VBP
# long RB
# slow JJ
# cartoonish NN
# write VBP
# infantil NNS
# like IN
# written VBN
# bunch NN
# prepubesc NN
# giggli NN
# teen JJ
# momoa NN
# charact NN
# overboard NN
# cant NN
# taken VBN
# long RB
# dose JJ
# basic JJ
# tri NN
# copi NN
# joker NN
# charact NN
# instead RB
# creat JJ
# persona JJ
# perform NN
# howev NN
# still RB
# engag VBZ
# entertain VBP
# dont VB
# even RB
# get VB
# start NN
# lame JJ
# end NN
# punish NN
# anyon NN
# follow VBP
# vin NN
# diesel NN
# social JJ
# medium NN
# constantli NN
# count NN
# day NN
# next IN
# ridicul JJ
# part NN
# fast NN
# x NN
# shouldv NN
# put VBD
# u JJ
# miseri JJ
# end NN
# franchis NN
# nice JJ
# even RB
# numbernevertheless VBP
# still RB
# decent JJ
# popcorn JJ
# watch NN
# riddl NN
# brainless NN
# expo NN
# plot NN
# hole NN
# nonsens NNS
# entertain VBP
# especi JJ
# noth DT
# better JJR
# almost RB
# hour NN
# wast NN
# fast JJ
# probabl NN
# peak NN
# mediocr NN
# couldnt NN
# imagin NN
# wors NNS
# immort VBP
# vin JJ
# diesel NN
# somehow RB
# manag RB
# much JJ
# wors NNS
# movi VBP
# isnt JJ
# mediocr NN
# realli NN
# stupid JJ
# plot NN
# complet NN
# nonsens NNS
# hilari JJ
# twist NN
# bad JJ
# cgi NN
# bad JJ
# act NN
# aw JJ
# scene NN
# realli VBP
# laugh IN
# especi NN
# rd NN
# actvin JJ
# diesel NN
# issu NN
# franchis VBD
# need JJ
# step NN
# reboot JJ
# whole JJ
# thing NN
# mayb NN
# someth RB
# good JJ
# saga NN
# realli NN
# much JJ
# crap NN
# even RB
# couldnt VBD
# enjoy JJ
# mamoa NN
# clich NN
# wasnt VBD
# worst JJS
# god NN
# hate NN
# way NN
# creat NN
# characterdont NN
# wast JJ
# time NN
# want VBP
# enjoy NN
# movi VB
# one CD
# isnt NN
# good JJ
# enough RB
# dont NN
# know VBP
# expect VBP
# movi JJ
# total JJ
# mess NN
# let NN
# tri VB
# stay VB
# posit JJ
# start NN
# good JJ
# pointth NN
# open JJ
# probabl NN
# best JJS
# part NN
# movi NN
# make VBP
# sure JJ
# enjoy VB
# addit JJ
# scene NN
# jacob NN
# surprisingli VBD
# good JJ
# funni NN
# hand NN
# scene NN
# roman NN
# tej NN
# arent NN
# funni NN
# anymor NN
# also RB
# need VBP
# stay NNS
# till VB
# post VBN
# credit NN
# scene NN
# would MD
# say VB
# worth JJ
# waitbut NNS
# enough RB
# good JJ
# thing NN
# stori JJ
# bad JJ
# normal JJ
# action NN
# compens NNS
# bad JJ
# stori JJ
# case NN
# action NN
# also RB
# one CD
# worst JJS
# seen VBN
# fast RB
# furiou JJ
# movi NN
# yet RB
# combin VBN
# even RB
# wors NNS
# vfx VBP
# furthermor NN
# car NN
# import NN
# aspect NN
# movi VBP
# one CD
# car NN
# play NN
# pretti VBP
# small JJ
# part NN
# call NN
# fast RB
# furiou JJ
# movi NN
# also RB
# movi VBZ
# long JJ
# see NN
# bad JJ
# action NN
# bad JJ
# action NN
# learn VBD
# new JJ
# charact NN
# relat JJ
# whole JJ
# famili NN
# boringand NN
# import NN
# question NN
# scene NN
# realist NN
# realli NN
# seen VBN
# car NN
# space NN
# scene NN
# rel NN
# realisticwith NN
# movi NN
# univers NNS
# want VBP
# make VB
# money NN
# complet NN
# forget VB
# u JJ
# fan NN
# watch NN
# forc NN
# watch NN
# next IN
# one CD
# spend NN
# even RB
# money NN
# bad JJ
# well RB
# think VBP
# everyth NNS
# hope VBP
# enjoy RB
# review VB
# know VB
# franchis JJ
# bankrupt JJ
# end NN
# cliffhang NN
# shrug JJ
# disinterestvin NN
# diesel NN
# walk VBP
# around IN
# look NN
# perpetu VBP
# constip NN
# villain NN
# jason NN
# mamoa NN
# seem VBP
# channel NNS
# heath NN
# ledger NN
# joker NN
# time NN
# former JJ
# stone NN
# cold NN
# bad JJ
# guy NN
# john NN
# cena NN
# goofi NN
# half NN
# road NN
# trip NN
# duo NN
# helen VBN
# mirren NNS
# queeni RB
# drop VBP
# one CD
# scene NN
# explan NN
# got VBD
# make JJ
# sen JJ
# strictli NN
# fan NN
# servic JJ
# michel NN
# rodriguez NN
# okay IN
# she PRP
# still RB
# hot JJ
# fine JJ
# scene NN
# even RB
# dumb VBZ
# one CD
# wake NN
# underground JJ
# prison NN
# antarctici NN
# thought VBD
# couldnt NNS
# get VB
# stupid JJ
# went VBD
# space NN
# last JJ
# movi NN
# wrong JJ
# action NN
# set VBN
# piec NN
# stupid JJ
# movi NN
# look NN
# wors NNS
# result VBP
# subpar JJ
# cgi NN
# earli NN
# crew VBD
# deal NN
# giant NN
# nuclear JJ
# bomb NN
# bowl NN
# ball NN
# roll NN
# endlessli JJ
# street NN
# rome JJ
# watch NN
# reaction NN
# face NN
# background NN
# crowd VBD
# scurri JJ
# way NN
# underwhelm JJ
# react NN
# someth VBZ
# digit RB
# insert JJ
# later RB
# youll JJ
# react NN
# wayit JJ
# surpris NN
# disappear VBP
# theatr NN
# quickli NN
#
# Dependency Parsing Tree:
# thought --> nsubj --> felt, children: [write]
# could --> aux --> possibl, children: []
# nt --> neg --> possibl, children: []
# possibl --> nsubj --> write, children: [could, nt]
# write --> ccomp --> thought, children: [possibl, someth, wors, hour]
# someth --> dobj --> write, children: []
# even --> advmod --> wors, children: []
# wors --> dobj --> write, children: [even]
# f --> nmod --> hour, children: []
# arethi --> amod --> hour, children: []
# movi --> amod --> hour, children: []
# excruci --> amod --> hour, children: []
# watch --> compound --> hour, children: []
# hour --> npadvmod --> write, children: [f, arethi, movi, excruci, watch]
# felt --> ROOT --> felt, children: [thought, like, end, better, forget, introduc, kill, make]
# like --> prep --> felt, children: []
# realli --> nmod --> scene, children: []
# long --> amod --> hour, children: []
# hour --> compound --> movi, children: [long]
# movi --> nmod --> scene, children: [hour]
# dumb --> amod --> scene, children: []
# action --> compound --> scene, children: []
# scene --> compound --> scene, children: [realli, movi, dumb, action]
# dumb --> amod --> scene, children: []
# action --> compound --> scene, children: []
# scene --> nsubj --> end, children: [scene, dumb, action]
# never --> neg --> end, children: []
# end --> ccomp --> felt, children: [scene, never, end, like, end]
# movi --> nsubj --> end, children: []
# end --> ccomp --> end, children: [movi, nowher]
# nowher --> dobj --> end, children: []
# like --> prep --> end, children: [show]
# even --> advmod --> show, children: []
# filler --> compound --> tv, children: []
# tv --> compound --> show, children: [filler]
# show --> pobj --> like, children: [even, tv]
# episod --> compound --> structur, children: []
# better --> amod --> stori, children: []
# stori --> compound --> structur, children: [better]
# structur --> nsubj --> end, children: [episod, stori]
# end --> conj --> end, children: [structur]
# thisthi --> compound --> movi, children: []
# movi --> nsubj --> better, children: [thisthi]
# might --> aux --> better, children: []
# better --> ccomp --> felt, children: [movi, might, understand]
# f --> nsubj --> understand, children: []
# understand --> ccomp --> better, children: [f, happen]
# sinc --> compound --> jason, children: []
# jason --> compound --> momoa, children: [sinc]
# momoa --> compound --> hell, children: [jason]
# hell --> nsubj --> happen, children: [momoa]
# do --> aux --> happen, children: []
# nt --> neg --> thing, children: []
# even --> advmod --> thing, children: []
# rememb --> amod --> thing, children: []
# thing --> nsubj --> happen, children: [nt, even, rememb]
# happen --> ccomp --> understand, children: [hell, do, thing]
# last --> amod --> movi, children: []
# movi --> nsubj --> forget, children: [last]
# wo --> aux --> forget, children: []
# nt --> neg --> forget, children: []
# forget --> conj --> felt, children: [movi, wo, nt, momoa, think]
# momoa --> dobj --> forget, children: []
# charact --> compound --> time, children: []
# time --> npadvmod --> think, children: [charact, get]
# soon --> advmod --> get, children: []
# get --> relcl --> time, children: [soon, watchabl]
# would --> aux --> watchabl, children: []
# watchabl --> ccomp --> get, children: [would, momoa]
# better --> amod --> momoa, children: []
# peopl --> compound --> momoa, children: []
# momoa --> dobj --> watchabl, children: [better, peopl]
# think --> ccomp --> forget, children: [time, get]
# wors --> nsubj --> momoa, children: []
# momoa --> nsubj --> get, children: [wors]
# charact --> nsubj --> get, children: []
# get --> ccomp --> think, children: [momoa, charact, kill]
# tire --> nsubj --> annoy, children: []
# annoy --> compound --> realli, children: [tire]
# realli --> nsubj --> fastth, children: [annoy]
# fastth --> nmod --> writer, children: [realli]
# biggest --> amod --> writer, children: []
# problem --> compound --> writer, children: []
# movi --> compound --> writer, children: []
# writer --> nsubj --> kill, children: [fastth, biggest, problem, movi]
# do --> aux --> ball, children: []
# nt --> neg --> ball, children: []
# ball --> nsubj --> kill, children: [do, nt, actual]
# actual --> amod --> ball, children: []
# kill --> ccomp --> get, children: [writer, ball, famili]
# main --> amod --> charact, children: []
# charact --> nmod --> famili, children: [main]
# actual --> amod --> famili, children: []
# hurt --> amod --> famili, children: []
# famili --> dobj --> kill, children: [charact, actual, hurt]
# instead --> advmod --> introduc, children: []
# introduc --> advcl --> felt, children: [instead, bring]
# new --> amod --> nowher, children: []
# charact --> compound --> nowher, children: []
# nowher --> nsubj --> bring, children: [new, charact]
# bring --> ccomp --> introduc, children: [nowher, back, charact]
# back --> advmod --> bring, children: []
# charact --> dobj --> bring, children: []
# fast --> amod --> five, children: []
# five --> nsubj --> kill, children: [fast]
# could --> aux --> kill, children: []
# kill --> ccomp --> felt, children: [five, could]
# instead --> advmod --> make, children: []
# make --> advcl --> felt, children: [instead, kill, brought, bring]
# dom --> nsubj --> care, children: []
# care --> nsubj --> kill, children: [dom, instead]
# instead --> advmod --> care, children: []
# actual --> advmod --> kill, children: []
# kill --> ccomp --> make, children: [care, actual, alreadi]
# real --> amod --> alreadi, children: []
# famili --> compound --> alreadi, children: []
# alreadi --> dobj --> kill, children: [real, famili]
# brought --> ccomp --> make, children: [back, charact, know]
# back --> prt --> brought, children: []
# mani --> compound --> charact, children: []
# charact --> dobj --> brought, children: [mani]
# dead --> amod --> know, children: []
# know --> npadvmod --> brought, children: [dead]
# would --> aux --> bring, children: []
# bring --> ccomp --> make, children: [would, back, one, kill, make]
# back --> advmod --> bring, children: []
# one --> dobj --> bring, children: []
# kill --> advcl --> bring, children: [unnecessari]
# fast --> amod --> mention, children: []
# mention --> compound --> unnecessari, children: [fast]
# unnecessari --> dobj --> kill, children: [mention]
# unfunni --> compound --> scene, children: []
# long --> amod --> scene, children: []
# scene --> nsubj --> make, children: [unfunni, long]
# contribut --> compound --> littl, children: []
# littl --> compound --> stori, children: [contribut]
# noth --> compound --> stori, children: []
# stori --> compound --> runtim, children: [littl, noth]
# pad --> compound --> runtim, children: []
# runtim --> nsubj --> make, children: [stori, pad]
# make --> conj --> bring, children: [scene, runtim, watch]
# want --> amod --> liter, children: []
# liter --> nsubj --> watch, children: [want]
# anyth --> compound --> continu, children: []
# el --> compound --> continu, children: []
# continu --> nsubj --> watch, children: [anyth, el]
# watch --> ccomp --> make, children: [liter, continu, like, davidsonther]
# like --> prep --> watch, children: [scene]
# black --> amod --> scene, children: []
# market --> compound --> scene, children: []
# scene --> pobj --> like, children: [black, market]
# ever --> advmod --> unfunni, children: []
# unfunni --> amod --> davidsonther, children: [ever]
# pete --> amod --> davidsonther, children: []
# davidsonther --> npadvmod --> watch, children: [unfunni, pete]
# aw --> intj --> amount, children: []
# amount --> nmod --> scene, children: [aw]
# long --> amod --> scene, children: []
# useless --> amod --> scene, children: []
# scene --> nsubj --> make, children: [amount, long, useless]
# make --> ROOT --> make, children: [scene, help, aw]
# sleepi --> compound --> movi, children: []
# movi --> nsubj --> realli, children: [sleepi]
# realli --> nmod --> scene, children: [movi]
# good --> amod --> insomnialik, children: []
# cure --> compound --> insomnialik, children: []
# insomnialik --> compound --> cut, children: [good, cure]
# cut --> compound --> scene, children: [insomnialik]
# tejromanramsey --> compound --> scene, children: []
# scene --> compound --> chang, children: [realli, cut, tejromanramsey]
# noth --> compound --> chang, children: []
# chang --> nsubj --> help, children: [scene, noth]
# actual --> amod --> help, children: []
# help --> ccomp --> make, children: [chang, actual]
# aw --> cc --> make, children: []
# pace --> compound --> movi, children: []
# movi --> nsubj --> get, children: [pace]
# get --> aux --> rid, children: [movi]
# rid --> ROOT --> rid, children: [get, time]
# unnecessari --> amod --> scene, children: []
# scene --> compound --> time, children: [unnecessari]
# noth --> compound --> plot, children: []
# plot --> compound --> time, children: [noth]
# time --> npadvmod --> rid, children: [scene, plot]
# breather --> nmod --> structur, children: [aw]
# aw --> cc --> breather, children: []
# action --> compound --> sceneth, children: []
# sceneth --> compound --> structur, children: [action]
# stori --> compound --> structur, children: []
# structur --> nsubj --> plain, children: [breather, sceneth, stori]
# plain --> advmod --> feel, children: [structur]
# aw --> intj --> feel, children: []
# movi --> nsubj --> feel, children: []
# feel --> ROOT --> feel, children: [plain, aw, movi, like, togeth, remind, knew, felt, care, wrote]
# like --> prep --> feel, children: [scene]
# bunch --> amod --> scene, children: []
# random --> amod --> scene, children: []
# action --> compound --> scene, children: []
# scene --> pobj --> like, children: [bunch, random, action]
# jumbl --> compound --> togeth, children: []
# togeth --> npadvmod --> feel, children: [jumbl, plot]
# actual --> amod --> plot, children: []
# plot --> appos --> togeth, children: [actual]
# structurecompar --> nmod --> stori, children: []
# storytel --> amod --> movi, children: []
# fast --> amod --> five, children: []
# five --> nummod --> movi, children: [fast]
# movi --> compound --> stori, children: [storytel, five]
# love --> compound --> use, children: []
# use --> compound --> lot, children: [love]
# lot --> compound --> stori, children: [use]
# footag --> compound --> stori, children: []
# retcon --> compound --> stori, children: []
# stori --> nsubj --> remind, children: [structurecompar, movi, lot, footag, retcon]
# remind --> ccomp --> feel, children: [stori, write]
# much --> advmod --> better, children: []
# better --> advmod --> write, children: [much]
# write --> xcomp --> remind, children: [better, ruin]
# action --> compound --> scene, children: []
# scene --> nmod --> ruin, children: [action]
# basic --> amod --> ruin, children: []
# ruin --> dobj --> write, children: [scene, basic, like]
# like --> prep --> ruin, children: [movi]
# old --> amod --> movi, children: []
# movi --> pobj --> like, children: [old]
# masterpiec --> amod --> writer, children: [least]
# least --> advmod --> masterpiec, children: []
# writer --> nsubj --> knew, children: [masterpiec]
# knew --> advcl --> feel, children: [writer, keep, written]
# keep --> xcomp --> knew, children: [action, keep]
# action --> dobj --> keep, children: []
# somewhat --> advmod --> ground, children: []
# ground --> nsubj --> keep, children: [somewhat]
# keep --> ccomp --> keep, children: [ground, mediocr]
# charact --> amod --> decent, children: []
# interest --> compound --> decent, children: []
# decent --> amod --> action, children: [charact, interest]
# balanc --> compound --> action, children: []
# action --> compound --> mediocr, children: [decent, balanc]
# dialogu --> amod --> movi, children: []
# characterizationthos --> compound --> movi, children: []
# movi --> compound --> mediocr, children: [dialogu, characterizationthos]
# mediocr --> dobj --> keep, children: [action, movi]
# written --> advcl --> knew, children: [least]
# least --> advmod --> written, children: []
# compet --> npadvmod --> mediocr, children: []
# mediocr --> compound --> charact, children: [compet]
# actual --> amod --> stori, children: []
# stori --> compound --> structur, children: [actual]
# structur --> compound --> charact, children: [stori]
# charact --> nsubj --> felt, children: [mediocr, structur]
# felt --> ccomp --> feel, children: [charact, like, realist]
# like --> prep --> felt, children: [ground]
# real --> amod --> ground, children: []
# human --> amod --> degre, children: []
# degre --> nmod --> ground, children: [human]
# actual --> amod --> entertain, children: []
# entertain --> nmod --> keep, children: [actual]
# bare --> amod --> keep, children: []
# minimum --> amod --> keep, children: []
# keep --> compound --> ground, children: [entertain, bare, minimum]
# ground --> pobj --> like, children: [real, degre, keep]
# realist --> xcomp --> felt, children: [charact]
# enough --> amod --> disbelief, children: []
# suspens --> compound --> disbelief, children: []
# disbelief --> nsubj --> charact, children: [enough, suspens]
# also --> advmod --> charact, children: []
# charact --> ccomp --> realist, children: [disbelief, also]
# would --> aux --> care, children: []
# care --> conj --> feel, children: [would, enough, feel, feel]
# enough --> advmod --> care, children: []
# watch --> compound --> hour, children: []
# hour --> compound --> movi, children: [watch]
# movi --> compound --> thatbut, children: [hour]
# thatbut --> nsubj --> feel, children: [movi, write]
# last --> amod --> movi, children: []
# two --> nummod --> movi, children: []
# movi --> npadvmod --> write, children: [last, two]
# worst --> advmod --> write, children: []
# write --> acl --> thatbut, children: [movi, worst, seen]
# i --> nsubj --> seen, children: []
# ve --> aux --> seen, children: []
# ever --> advmod --> seen, children: []
# seen --> ccomp --> write, children: [i, ve, ever]
# feel --> advcl --> care, children: [thatbut, like]
# like --> prep --> feel, children: []
# were --> auxpass --> written, children: []
# nt --> neg --> written, children: []
# even --> advmod --> written, children: []
# written --> amod --> feel, children: [were, nt, even]
# adult --> nmod --> imagin, children: []
# human --> amod --> dialogu, children: []
# worst --> amod --> dialogu, children: []
# dialogu --> amod --> imagin, children: [human, worst]
# imagin --> nmod --> feel, children: [adult, dialogu, one]
# one --> nummod --> imagin, children: []
# particular --> amod --> feel, children: []
# feel --> conj --> care, children: [written, imagin, particular, like]
# like --> prep --> feel, children: [b]
# collag --> compound --> b, children: []
# random --> compound --> b, children: []
# b --> pobj --> like, children: [collag, random]
# wrote --> conj --> feel, children: [stori]
# stori --> dobj --> wrote, children: []
# boardthey --> nsubj --> tri, children: []
# also --> advmod --> tri, children: []
# tri --> dep --> make, children: [boardthey, also, make]
# make --> xcomp --> tri, children: [take]
# take --> xcomp --> make, children: []
# everyth --> advmod --> serious, children: []
# serious --> amod --> alon, children: [everyth]
# point --> compound --> alon, children: []
# alon --> nsubj --> make, children: [serious, point]
# make --> ROOT --> make, children: [tri, alon, add, end]
# hilari --> nsubj --> add, children: []
# add --> ccomp --> make, children: [hilari, ridicul]
# jester --> compound --> ridicul, children: []
# villain --> compound --> mix, children: []
# mix --> compound --> ridicul, children: [villain]
# ridicul --> compound --> ridicul, children: [mix]
# amalgam --> compound --> ridicul, children: []
# ridicul --> dobj --> add, children: [jester, ridicul, amalgam]
# want --> aux --> take, children: []
# take --> csubj --> end, children: [want, serious]
# serious --> advmod --> take, children: []
# ca --> aux --> alreadi, children: [nt]
# nt --> neg --> ca, children: []
# anyth --> compound --> movi, children: []
# roll --> compound --> facepalmth, children: []
# eye --> compound --> facepalmth, children: []
# facepalmth --> compound --> movi, children: [roll, eye]
# movi --> compound --> alreadi, children: [anyth, facepalmth]
# alreadi --> compound --> want, children: [ca, movi]
# bad --> amod --> want, children: []
# want --> nsubj --> end, children: [alreadi, bad]
# end --> ccomp --> make, children: [take, want, badli]
# badli --> dobj --> end, children: []
# earli --> nsubj --> end, children: []
# end --> ROOT --> end, children: [earli, insult, list, time, care, make, feel, differ, write]
# bad --> amod --> insult, children: []
# insult --> dobj --> end, children: [bad]
# honestlyal --> amod --> lot, children: []
# lot --> compound --> list, children: [honestlyal]
# problem --> compound --> care, children: []
# care --> compound --> list, children: [problem]
# list --> dobj --> end, children: [lot, care]
# wast --> compound --> time, children: []
# time --> npadvmod --> end, children: [wast]
# talk --> compound --> garbag, children: []
# garbag --> nsubj --> care, children: [talk, along]
# along --> prep --> garbag, children: [alreadi]
# fact --> compound --> alreadi, children: []
# alreadi --> pobj --> along, children: [fact]
# did --> aux --> care, children: []
# nt --> neg --> care, children: []
# care --> ccomp --> end, children: [garbag, did, nt]
# ounc --> compound --> stori, children: []
# charact --> compound --> stori, children: []
# stori --> compound --> f, children: [ounc, charact]
# f --> nsubj --> make, children: [stori]
# make --> dep --> end, children: [f, previou]
# movi --> compound --> wors, children: []
# wors --> nsubj --> previou, children: [movi]
# previou --> ccomp --> make, children: [wors, one]
# one --> dobj --> previou, children: []
# get --> aux --> feel, children: []
# somehow --> advmod --> feel, children: []
# feel --> ccomp --> end, children: [get, somehow, go]
# like --> mark --> go, children: []
# even --> advmod --> go, children: []
# go --> advcl --> feel, children: [like, even, u, wors]
# lower --> amod --> u, children: []
# deliv --> compound --> u, children: []
# u --> dobj --> go, children: [lower, deliv]
# even --> advmod --> wors, children: []
# wors --> attr --> go, children: [even, movi]
# mess --> compound --> movi, children: []
# movi --> dobj --> wors, children: [mess]
# next --> nmod --> appar, children: []
# one --> nummod --> appar, children: []
# writer --> compound --> appar, children: []
# appar --> nsubj --> differ, children: [next, one, writer]
# differ --> conj --> end, children: [appar, see]
# experienc --> compound --> wait, children: []
# wait --> nsubj --> see, children: [experienc]
# see --> advcl --> differ, children: [wait, save, set]
# doubt --> amod --> anyon, children: []
# anyon --> nsubj --> save, children: [doubt]
# could --> aux --> save, children: []
# save --> ccomp --> see, children: [anyon, could]
# point --> compound --> movi, children: []
# movi --> nsubj --> set, children: [point]
# set --> ccomp --> see, children: [movi, possibl]
# lowest --> amod --> possibl, children: []
# bar --> compound --> possibl, children: []
# possibl --> dobj --> set, children: [lowest, bar]
# must --> aux --> write, children: []
# actual --> amod --> geniu, children: []
# geniu --> nsubj --> write, children: [actual]
# somehow --> advmod --> write, children: []
# write --> conj --> end, children: [must, geniu, somehow, wors, fast, transform]
# someth --> amod --> wors, children: []
# wors --> dobj --> write, children: [someth]
# fast --> advmod --> write, children: [write]
# x --> punct --> script, children: []
# script --> npadvmod --> write, children: [x]
# write --> prep --> fast, children: [script, review]
# exact --> amod --> review, children: []
# review --> dative --> write, children: [exact]
# last --> amod --> transform, children: []
# transform --> dobj --> write, children: [last]
# last --> amod --> indiana, children: []
# indiana --> compound --> jone, children: [last]
# jone --> ROOT --> jone, children: [indiana, movi]
# last --> amod --> movi, children: []
# star --> compound --> war, children: []
# war --> compound --> movi, children: [star]
# movi --> appos --> jone, children: [last, war]
# last --> amod --> movi, children: []
# ff --> intj --> movi, children: []
# last --> amod --> marvel, children: []
# marvel --> compound --> movi, children: [last]
# movi --> nmod --> movi, children: [last, ff, marvel]
# etc --> compound --> peopl, children: []
# happan --> compound --> peopl, children: []
# peopl --> compound --> someth, children: [etc, happan]
# someth --> compound --> movi, children: [peopl]
# happen --> compound --> movi, children: []
# movi --> nsubj --> industri, children: [movi, someth, happen]
# industri --> ROOT --> industri, children: [movi, late, see, come, changesit, insist]
# late --> advmod --> industri, children: []
# can --> aux --> see, children: []
# not --> neg --> see, children: []
# see --> advcl --> industri, children: [can, not, charact]
# decent --> amod --> plot, children: []
# plot --> compound --> consist, children: [decent]
# consist --> compound --> sympathet, children: [plot]
# storytel --> compound --> sympathet, children: []
# sympathet --> compound --> charact, children: [consist, storytel]
# charact --> dobj --> see, children: [sympathet]
# anymor --> compound --> day, children: []
# day --> compound --> day, children: [anymor]
# day --> npadvmod --> charact, children: [day]
# endur --> compound --> imbecil, children: []
# imbecil --> compound --> movi, children: [endur]
# movi --> compound --> idiot, children: [imbecil]
# idiot --> nsubj --> charact, children: [movi]
# charact --> nsubj --> come, children: [day, idiot, movi]
# new --> amod --> movi, children: []
# movi --> dobj --> charact, children: [new]
# come --> conj --> industri, children: [charact, pattern]
# pattern --> dobj --> come, children: []
# never --> neg --> changesit, children: []
# changesit --> conj --> industri, children: [never]
# realli --> compound --> movielov, children: []
# easi --> compound --> movielov, children: []
# job --> compound --> movielov, children: []
# movielov --> compound --> imdb, children: [realli, easi, job]
# p --> nmod --> trend, children: []
# see --> compound --> trend, children: []
# trend --> compound --> imdb, children: [p, see]
# imdb --> nsubj --> insist, children: [movielov, trend]
# insist --> conj --> industri, children: [imdb, limit]
# minimum --> amod --> charact, children: []
# charact --> compound --> limit, children: [minimum]
# limit --> ccomp --> insist, children: [charact]
# oh --> intj --> furiou, children: []
# fast --> amod --> furiou, children: []
# furiou --> compound --> lot, children: [oh, fast]
# lot --> nsubj --> took, children: [furiou, point]
# franchis --> det --> point, children: []
# point --> npadvmod --> lot, children: [franchis]
# took --> ccomp --> go, children: [lot, space, seem, roll, go, end, get, x, dumb, film, enhanc, ropey, attempt, anoth, barbecu, think, dantei]
# action --> nmod --> space, children: []
# outer --> amod --> space, children: []
# space --> dobj --> took, children: [action, outer]
# seem --> dep --> took, children: [quit]
# like --> mark --> quit, children: []
# good --> amod --> call, children: []
# point --> compound --> call, children: []
# call --> nsubj --> quit, children: [good, point]
# quit --> advcl --> seem, children: [like, call, money]
# money --> dobj --> quit, children: []
# still --> advmod --> roll, children: []
# roll --> dep --> took, children: [still]
# nobodi --> compound --> hollywood, children: []
# hollywood --> compound --> go, children: [nobodi]
# go --> dep --> took, children: [hollywood]
# end --> conj --> took, children: [thu]
# cash --> compound --> cow, children: []
# cow --> compound --> thu, children: [cash]
# thu --> dobj --> end, children: [cow]
# fast --> amod --> part, children: []
# x --> punct --> part, children: []
# first --> amod --> part, children: []
# rumour --> compound --> three, children: []
# three --> nummod --> part, children: [rumour]
# part --> nmod --> board, children: [fast, x, first, three]
# final --> amod --> board, children: []
# inevit --> compound --> board, children: []
# reboot --> compound --> board, children: []
# board --> nmod --> action, children: [part, final, inevit, reboot, stick]
# franchis --> compound --> stick, children: []
# sinc --> compound --> stick, children: []
# start --> compound --> stick, children: []
# stick --> appos --> board, children: [franchis, sinc, start]
# move --> compound --> street, children: []
# street --> nmod --> world, children: [move]
# race --> compound --> world, children: []
# world --> nmod --> action, children: [street, race]
# jame --> compound --> bond, children: []
# bond --> compound --> territori, children: [jame]
# territori --> compound --> action, children: [bond]
# action --> nsubj --> get, children: [board, world, territori]
# get --> conj --> took, children: [action, see]
# ridicul --> compound --> chapter, children: []
# chapter --> nsubj --> see, children: [ridicul]
# see --> ccomp --> get, children: [chapter, top]
# movi --> nsubj --> top, children: []
# would --> aux --> top, children: []
# top --> ccomp --> see, children: [movi, would, crazi]
# one --> nummod --> crazi, children: []
# term --> compound --> crazi, children: []
# crazi --> dobj --> top, children: [one, term, kept]
# kept --> acl --> crazi, children: [entertain]
# entertain --> oprd --> kept, children: [fast]
# fast --> advmod --> entertain, children: []
# x --> punct --> took, children: []
# dumb --> advcl --> took, children: []
# even --> advmod --> preposter, children: []
# dumb --> amod --> preposter, children: []
# funth --> amod --> preposter, children: []
# stunt --> compound --> preposter, children: []
# preposter --> nsubj --> film, children: [even, dumb, funth, stunt]
# ever --> advmod --> film, children: []
# film --> advcl --> took, children: [preposter, ever, thrill]
# never --> neg --> thrill, children: []
# thrill --> prep --> film, children: [never]
# everi --> amod --> scene, children: []
# intermin --> compound --> scene, children: []
# action --> compound --> scene, children: []
# scene --> nsubj --> enhanc, children: [everi, intermin, action]
# enhanc --> conj --> took, children: [scene]
# rather --> advmod --> ropey, children: []
# ropey --> conj --> took, children: [rather]
# cgi --> compound --> flame, children: []
# flame --> nmod --> attempt, children: [cgi]
# particular --> amod --> attempt, children: []
# look --> nmod --> attempt, children: []
# realli --> nmod --> dread, children: []
# bad --> amod --> dread, children: []
# dread --> compound --> attempt, children: [realli, bad]
# attempt --> dep --> took, children: [flame, particular, look, dread, get]
# humour --> compound --> ludacri, children: []
# mostli --> compound --> ludacri, children: []
# courtesi --> compound --> ludacri, children: []
# tyre --> compound --> ludacri, children: []
# gibson --> compound --> ludacri, children: []
# ludacri --> nsubj --> get, children: [humour, mostli, courtesi, tyre, gibson]
# get --> ccomp --> attempt, children: [ludacri, see]
# inevit --> nsubj --> crap, children: []
# crap --> compound --> famili, children: [inevit]
# import --> compound --> famili, children: []
# famili --> nsubj --> see, children: [crap, import]
# see --> ccomp --> get, children: [famili]
# gang --> compound --> anoth, children: []
# anoth --> npadvmod --> took, children: [gang]
# barbecu --> cc --> took, children: []
# think --> conj --> took, children: [hurland]
# ill --> amod --> hurland, children: []
# hurland --> dobj --> think, children: [ill, there]
# there --> advmod --> hurland, children: []
# jason --> compound --> momoa, children: []
# momoa --> compound --> dantei, children: [jason]
# villain --> compound --> dantei, children: []
# dantei --> dep --> took, children: [momoa, villain]
# see --> aux --> go, children: []
# go --> ROOT --> go, children: [took, see, capabl, absolut, aw, perform, help, choic, find, watch]
# kooki --> compound --> psycho, children: []
# flamboy --> compound --> psycho, children: []
# psycho --> nsubj --> capabl, children: [kooki, flamboy]
# capabl --> ccomp --> go, children: [psycho, anyth, momoa]
# almost --> advmod --> anyth, children: []
# anyth --> dobj --> capabl, children: [almost]
# momoa --> npadvmod --> capabl, children: []
# absolut --> advmod --> go, children: []
# aw --> cc --> go, children: []
# perform --> advcl --> go, children: [camp]
# border --> compound --> camp, children: []
# ...
# still --> advmod --> decent, children: []
# decent --> amod --> popcorn, children: [still]
# popcorn --> nsubj --> watch, children: [numbernevertheless, decent]
# watch --> conj --> go, children: [popcorn, hole]
# riddl --> compound --> hole, children: []
# brainless --> compound --> hole, children: []
# expo --> compound --> hole, children: []
# plot --> compound --> hole, children: []
# hole --> dobj --> watch, children: [riddl, brainless, expo, plot]
# nonsens --> compound --> entertain, children: []
# entertain --> nsubj --> especi, children: [nonsens]
# especi --> nsubj --> imagin, children: [entertain, noth, better]
# noth --> dobj --> especi, children: []
# better --> advmod --> especi, children: [almost]
# almost --> advmod --> better, children: []
# hour --> nmod --> mediocr, children: []
# wast --> nmod --> peak, children: []
# fast --> amod --> probabl, children: []
# probabl --> amod --> peak, children: [fast]
# peak --> compound --> mediocr, children: [wast, probabl]
# mediocr --> nsubj --> imagin, children: [hour, peak]
# could --> aux --> imagin, children: []
# nt --> neg --> imagin, children: []
# imagin --> advcl --> go, children: [especi, mediocr, could, nt, wors]
# wors --> dobj --> imagin, children: []
# immort --> compound --> diesel, children: []
# vin --> compound --> diesel, children: []
# diesel --> nsubj --> manag, children: [immort, vin]
# somehow --> advmod --> manag, children: []
# manag --> conj --> go, children: [diesel, somehow]
# much --> amod --> wors, children: []
# wors --> compound --> movi, children: [much]
# movi --> nsubj --> is, children: [wors]
# is --> conj --> go, children: [movi, nt, complet]
# nt --> neg --> is, children: []
# mediocr --> compound --> realli, children: []
# realli --> nmod --> complet, children: [mediocr]
# stupid --> amod --> complet, children: []
# plot --> compound --> complet, children: []
# complet --> attr --> is, children: [realli, stupid, plot, act]
# nonsens --> compound --> act, children: []
# hilari --> compound --> act, children: []
# twist --> nmod --> act, children: []
# bad --> amod --> act, children: []
# cgi --> nmod --> act, children: []
# bad --> amod --> act, children: []
# act --> appos --> complet, children: [nonsens, hilari, twist, bad, cgi, bad]
# aw --> intj --> laugh, children: []
# scene --> compound --> laugh, children: []
# realli --> compound --> laugh, children: []
# laugh --> nsubj --> especi, children: [aw, scene, realli]
# especi --> nsubj --> need, children: [laugh, rd, franchis, thing, mayb, realli, crap, enjoy, hate, want, are]
# rd --> npadvmod --> especi, children: []
# actvin --> compound --> diesel, children: []
# diesel --> compound --> franchis, children: [actvin]
# issu --> compound --> franchis, children: []
# franchis --> dobj --> especi, children: [diesel, issu]
# need --> compound --> step, children: []
# step --> nmod --> thing, children: [need, reboot]
# reboot --> prep --> step, children: []
# whole --> amod --> thing, children: []
# thing --> dobj --> especi, children: [step, whole]
# mayb --> npadvmod --> especi, children: []
# someth --> amod --> saga, children: []
# good --> amod --> saga, children: []
# saga --> compound --> realli, children: [someth, good]
# realli --> dobj --> especi, children: [saga]
# much --> amod --> crap, children: []
# crap --> dobj --> especi, children: [much]
# even --> advmod --> enjoy, children: []
# could --> aux --> enjoy, children: []
# nt --> neg --> enjoy, children: []
# enjoy --> advcl --> especi, children: [even, could, nt, was]
# mamoa --> compound --> clich, children: []
# clich --> nsubj --> was, children: [mamoa]
# was --> ccomp --> enjoy, children: [clich, worst]
# nt --> neg --> worst, children: []
# worst --> acomp --> was, children: [nt]
# god --> nsubj --> hate, children: []
# hate --> dep --> especi, children: [god, way, characterdont, time]
# way --> dobj --> hate, children: []
# creat --> compound --> characterdont, children: []
# characterdont --> dobj --> hate, children: [creat]
# wast --> compound --> time, children: []
# time --> npadvmod --> hate, children: [wast]
# want --> advcl --> especi, children: [enjoy, is]
# enjoy --> xcomp --> want, children: []
# movi --> compound --> one, children: []
# one --> nsubj --> is, children: [movi]
# is --> ccomp --> want, children: [one, nt, good, know]
# nt --> neg --> is, children: []
# good --> acomp --> is, children: [enough]
# enough --> advmod --> good, children: []
# do --> aux --> know, children: []
# nt --> neg --> know, children: []
# know --> xcomp --> is, children: [do, nt, expect]
# expect --> xcomp --> know, children: [let]
# movi --> compound --> mess, children: []
# total --> amod --> mess, children: []
# mess --> nsubj --> let, children: [movi, total]
# let --> ccomp --> expect, children: [mess, make]
# tri --> nsubj --> stay, children: []
# stay --> nsubj --> start, children: [tri, posit]
# posit --> dobj --> stay, children: []
# start --> nsubj --> pointth, children: [stay]
# good --> amod --> pointth, children: []
# pointth --> compound --> movi, children: [start, good]
# open --> amod --> part, children: []
# probabl --> nmod --> part, children: []
# best --> amod --> part, children: []
# part --> compound --> movi, children: [open, probabl, best]
# movi --> nsubj --> make, children: [pointth, part]
# make --> ccomp --> let, children: [movi, enjoy, roman]
# sure --> nsubj --> enjoy, children: []
# enjoy --> ccomp --> make, children: [sure]
# addit --> compound --> scene, children: []
# scene --> compound --> scene, children: [addit]
# jacob --> compound --> surprisingli, children: []
# surprisingli --> compound --> scene, children: [jacob]
# good --> compound --> scene, children: []
# funni --> compound --> scene, children: []
# hand --> compound --> scene, children: []
# scene --> nsubj --> roman, children: [scene, surprisingli, good, funni, hand]
# roman --> ccomp --> make, children: [scene, tej]
# tej --> dobj --> roman, children: []
# are --> aux --> especi, children: [nt, anymor]
# nt --> neg --> are, children: []
# funni --> compound --> anymor, children: []
# anymor --> attr --> are, children: [funni]
# also --> advmod --> need, children: []
# need --> ROOT --> need, children: [especi, also, stay, combin, play, call, see, rel, want, spend]
# stay --> dobj --> need, children: [say]
# till --> mark --> say, children: []
# post --> compound --> scene, children: []
# credit --> compound --> scene, children: []
# scene --> nsubj --> say, children: [post, credit]
# would --> aux --> say, children: []
# say --> advcl --> stay, children: [till, scene, would, worth, seen]
# worth --> acomp --> say, children: [waitbut]
# waitbut --> xcomp --> worth, children: [action]
# enough --> amod --> action, children: []
# good --> amod --> thing, children: []
# thing --> compound --> stori, children: [good]
# stori --> nmod --> compens, children: [thing]
# bad --> amod --> compens, children: []
# normal --> amod --> compens, children: []
# action --> compound --> compens, children: []
# compens --> npadvmod --> bad, children: [stori, bad, normal, action]
# bad --> amod --> case, children: [compens]
# stori --> compound --> case, children: []
# case --> compound --> action, children: [bad, stori]
# action --> dobj --> waitbut, children: [enough, case]
# also --> advmod --> one, children: []
# one --> nsubj --> seen, children: [also]
# worst --> advmod --> seen, children: []
# seen --> ccomp --> say, children: [one, worst, movi, yet]
# fast --> amod --> furiou, children: []
# furiou --> compound --> movi, children: [fast]
# movi --> dobj --> seen, children: [furiou]
# yet --> advmod --> seen, children: []
# combin --> prep --> need, children: [wors]
# even --> advmod --> wors, children: []
# wors --> pobj --> combin, children: [even, movi]
# vfx --> nmod --> aspect, children: []
# furthermor --> compound --> car, children: []
# car --> compound --> import, children: [furthermor]
# import --> compound --> aspect, children: [car]
# aspect --> compound --> movi, children: [vfx, import]
# movi --> appos --> wors, children: [aspect]
# one --> nummod --> car, children: []
# car --> compound --> play, children: [one]
# play --> conj --> need, children: [car]
# pretti --> nmod --> part, children: []
# small --> amod --> part, children: []
# part --> nsubj --> call, children: [pretti, small]
# call --> conj --> need, children: [part, movi]
# fast --> amod --> movi, children: []
# furiou --> compound --> movi, children: []
# movi --> dobj --> call, children: [fast, furiou]
# also --> advmod --> see, children: []
# movi --> aux --> see, children: []
# long --> advmod --> see, children: []
# see --> dep --> need, children: [also, movi, long, learn]
# bad --> amod --> action, children: []
# action --> npadvmod --> bad, children: []
# bad --> amod --> action, children: [action]
# action --> nsubj --> learn, children: [bad, bad]
# learn --> ccomp --> see, children: [action, scene]
# new --> amod --> charact, children: []
# charact --> nsubj --> relat, children: [new]
# relat --> nmod --> scene, children: [charact]
# whole --> amod --> famili, children: []
# famili --> nmod --> import, children: [whole]
# boringand --> compound --> import, children: []
# import --> compound --> question, children: [famili, boringand]
# question --> compound --> scene, children: [import]
# scene --> dobj --> learn, children: [relat, question, seen]
# realist --> compound --> realli, children: []
# realli --> nsubj --> seen, children: [realist]
# seen --> relcl --> scene, children: [realli]
# car --> compound --> space, children: []
# space --> compound --> scene, children: [car]
# scene --> compound --> rel, children: [space]
# rel --> advcl --> need, children: [scene]
# realisticwith --> mark --> want, children: []
# movi --> compound --> univers, children: []
# univers --> nsubj --> want, children: [movi]
# want --> advcl --> need, children: [realisticwith, univers, make]
# make --> xcomp --> want, children: [forget]
# money --> compound --> complet, children: []
# complet --> nsubj --> forget, children: [money]
# forget --> ccomp --> make, children: [complet, u]
# u --> punct --> forget, children: []
# fan --> compound --> watch, children: []
# watch --> compound --> watch, children: [fan]
# forc --> compound --> watch, children: []
# watch --> nsubj --> spend, children: [watch, forc]
# next --> amod --> one, children: []
# one --> nsubj --> spend, children: [next]
# spend --> advcl --> need, children: [watch, one, bad]
# even --> advmod --> money, children: []
# money --> npadvmod --> bad, children: [even]
# bad --> acomp --> spend, children: [money]
# well --> intj --> think, children: []
# think --> ROOT --> think, children: [well, hope, seem]
# everyth --> nsubj --> hope, children: []
# hope --> ccomp --> think, children: [everyth, know]
# enjoy --> compound --> review, children: []
# review --> nsubj --> know, children: [enjoy]
# know --> ccomp --> hope, children: [review, end]
# franchis --> det --> end, children: []
# bankrupt --> amod --> end, children: []
# end --> dobj --> know, children: [franchis, bankrupt, walk]
# cliffhang --> compound --> shrug, children: []
# shrug --> compound --> diesel, children: [cliffhang]
# disinterestvin --> compound --> diesel, children: []
# diesel --> nsubj --> walk, children: [shrug, disinterestvin]
# walk --> relcl --> end, children: [diesel, around]
# around --> advmod --> walk, children: []
# look --> intj --> seem, children: []
# perpetu --> compound --> constip, children: []
# constip --> compound --> mamoa, children: [perpetu]
# villain --> compound --> mamoa, children: []
# jason --> compound --> mamoa, children: []
# mamoa --> nsubj --> seem, children: [constip, villain, jason]
# seem --> ccomp --> think, children: [look, mamoa, time, drop]
# channel --> compound --> ledger, children: []
# heath --> compound --> ledger, children: []
# ledger --> compound --> joker, children: [channel, heath]
# joker --> compound --> time, children: [ledger]
# time --> npadvmod --> seem, children: [joker]
# former --> amod --> guy, children: []
# stone --> nmod --> guy, children: []
# cold --> amod --> bad, children: []
# bad --> amod --> guy, children: [cold]
# guy --> compound --> mirren, children: [former, stone, bad]
# john --> compound --> cena, children: []
# cena --> nmod --> mirren, children: [john]
# goofi --> nmod --> half, children: []
# half --> nmod --> duo, children: [goofi]
# road --> compound --> trip, children: []
# trip --> compound --> duo, children: [road]
# duo --> compound --> mirren, children: [half, trip]
# helen --> compound --> mirren, children: []
# mirren --> nsubj --> drop, children: [guy, cena, duo, helen]
# queeni --> nsubj --> drop, children: []
# drop --> conj --> seem, children: [mirren, queeni, got]
# one --> nummod --> scene, children: []
# scene --> compound --> explan, children: [one]
# explan --> nsubj --> got, children: [scene]
# got --> ccomp --> drop, children: [explan, make]
# make --> xcomp --> got, children: []
# sen --> compound --> rodriguez, children: []
# strictli --> compound --> fan, children: []
# fan --> compound --> michel, children: [strictli]
# servic --> compound --> michel, children: []
# michel --> compound --> rodriguez, children: [fan, servic]
# rodriguez --> ROOT --> rodriguez, children: [sen, michel]
# okay --> ROOT --> okay, children: []
# she --> nsubj --> wake, children: [scene]
# still --> advmod --> scene, children: []
# hot --> amod --> scene, children: []
# fine --> amod --> scene, children: []
# scene --> appos --> she, children: [still, hot, fine, dumb]
# even --> advmod --> dumb, children: []
# dumb --> amod --> scene, children: [even]
# one --> nummod --> wake, children: []
# wake --> ROOT --> wake, children: [she, one, thought, get, action, set, look, result, disappear, quickli]
# underground --> amod --> thought, children: []
# prison --> compound --> antarctici, children: []
# antarctici --> compound --> thought, children: [prison]
# thought --> dobj --> wake, children: [underground, antarctici]
# could --> aux --> get, children: []
# nt --> neg --> get, children: []
# get --> xcomp --> wake, children: [could, nt, stupid, space]
# stupid --> acomp --> get, children: []
# went --> amod --> space, children: []
# space --> dobj --> get, children: [went]
# last --> amod --> movi, children: []
# movi --> nmod --> action, children: [last]
# wrong --> amod --> action, children: []
# action --> npadvmod --> wake, children: [movi, wrong]
# set --> xcomp --> wake, children: [movi]
# piec --> nmod --> movi, children: []
# stupid --> amod --> movi, children: []
# movi --> dobj --> set, children: [piec, stupid]
# look --> conj --> wake, children: []
# wors --> nsubj --> result, children: []
# result --> conj --> wake, children: [wors, crowd, react]
# subpar --> nmod --> crew, children: []
# cgi --> nmod --> crew, children: []
# earli --> compound --> crew, children: []
# crew --> compound --> deal, children: [subpar, cgi, earli]
# deal --> nsubj --> crowd, children: [crew]
# giant --> amod --> bowl, children: []
# nuclear --> amod --> bomb, children: []
# bomb --> compound --> bowl, children: [nuclear]
# bowl --> compound --> ball, children: [giant, bomb]
# ball --> compound --> rome, children: [bowl]
# roll --> compound --> rome, children: []
# endlessli --> compound --> rome, children: []
# street --> compound --> rome, children: []
# rome --> compound --> reaction, children: [ball, roll, endlessli, street]
# watch --> compound --> reaction, children: []
# reaction --> compound --> face, children: [rome, watch]
# face --> compound --> background, children: [reaction]
# background --> nsubj --> crowd, children: [face]
# crowd --> ccomp --> result, children: [deal, background, way]
# scurri --> amod --> way, children: []
# way --> dobj --> crowd, children: [scurri, react]
# underwhelm --> nsubj --> react, children: []
# react --> relcl --> way, children: [underwhelm, insert]
# someth --> compound --> digit, children: []
# digit --> compound --> insert, children: [someth]
# insert --> dobj --> react, children: [digit]
# later --> advmod --> react, children: []
# you --> nsubj --> react, children: []
# ll --> aux --> react, children: []
# react --> advcl --> result, children: [later, you, ll, surpris]
# wayit --> compound --> surpris, children: []
# surpris --> dobj --> react, children: [wayit]
# disappear --> conj --> wake, children: [theatr]
# theatr --> dobj --> disappear, children: []
# quickli --> npadvmod --> wake, children: []
# Named Entities:
# TIME: 3
# CARDINAL: 33
# ORG: 15
# PERSON: 55
# DATE: 11
# GPE: 11
# ORDINAL: 9
# NORP: 12
# WORK_OF_ART: 1

# %% [markdown]
# In natural language processing, there are two ways for analysing phrase syntactic structure: constituent parsing and dependency parsing. A constituency parsing tree depicts a sentence's hierarchical structure by breaking it down into sub-phrases or "constituents" that correspond to certain grammatical categories like noun phrases (NP) or verb phrases (VP). This tree shows how words gather together to make phrases, which then combine to produce sentences. A dependency parsing tree, on the other hand, is concerned with word connections, distinguishing the "head" words (which can be verbs, nouns, and so on) and their "dependents" (words that alter or complement the head). It depicts the phrase as a network of nodes (words) linked by edges (dependencies), demonstrating how words rely on one another to express meaning. While constituency parsing shows the sentence's layered structure, dependency parsing offers a direct map of syntactic interactions, which is useful for analysing grammatical relationships and specific word functions.

# %% [markdown]
# # Mandatory Question
#
# Provide your thoughts on the assignment. What did you find challenging, and what aspects did you enjoy? Your opinion on the provided time to complete the assignment.

# %% [markdown]
# The assignment appears to be comprehensive and multifaceted, targeting both practical skills in data collection via web scraping or APIs and theoretical understanding of natural language processing (NLP) concepts. The challenges likely arise from the initial phase of collecting a large dataset, which requires proficiency in handling web data extraction techniques and understanding API usage. Additionally, cleaning and structuring the data for analysis can be time-consuming. The syntactic analysis part demands a good grasp of NLP concepts like POS tagging, parsing, and named entity recognition, which can be complex but are fundamental to text analysis. Enjoyable aspects might include the satisfaction of successfully collecting and analyzing data, gaining insights from raw text, and applying theoretical knowledge to practical scenarios. The time provided for the assignment seems fair, although it heavily depends on prior experience with Python programming, NLP, and data manipulation techniques. Completing this assignment would offer a holistic view of the text data processing pipeline, from collection to syntactic analysis, which is valuable for anyone interested in data science or NLP.
